# %%
import numpy as np

# %%
# 一次元配列の作り方
a = np.array([1, 2, 3])
a
# Out:
# array([1, 2, 3])

# %%
# 配列の指定
a[2] = 4
a
# Out:
# array([1, 2, 4])

# %%
# 一次元配列を二次元配列にする
b = np.array([1, 2, 3, 4, 5, 6])
b = b.reshape(2, 3)
b
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
# 指定の変数を変更できる
b[1, 2] = 7
b
# Out:
# array([[1, 2, 3],
#        [4, 5, 7]])

# %%
# 列数もまとめて変更できる
b[:, 2] = 8
b
# Out:
# array([[1, 2, 8],
#        [4, 5, 8]])
