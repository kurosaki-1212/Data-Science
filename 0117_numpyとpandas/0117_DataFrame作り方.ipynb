# %%
import pandas as pd

# %%
# DataFrameの作り方
df = pd.DataFrame([[10, "a", True], 
                   [20, "b", False], 
                   [30, "c", False], 
                   [40, "d", True]])
df
# Out:
#     0  1      2
# 0  10  a   True
# 1  20  b  False
# 2  30  c  False
# 3  40  d   True
