# %% [markdown]
# # Matplotlib
# ### ◆Matplotlibを使うための準備、各種ライブラリのインポート

# %%
# Matplotlib と Seabornの読み込み
# Seabornはきれいに図示できる
import matplotlib as mpl
import seaborn as sns

# pyplotにはpltの別名で実行できるようにする
import matplotlib.pyplot as plt

# Jupyter Notebook上でグラフを表示させるために必要なマジックコマンド
# %matplotlib inline

# %% [markdown]
# ### ◆Numpy, Scipy, Pandas のインポート

# %%
# Numpy, Scipy, Pandasのインポート
import numpy as np
import numpy.random as random
import scipy as sp
import pandas as pd
from pandas import Series, DataFrame

# 小数第3位まで表示
# %precision 3
# Out:
# '%.3f'

# %% [markdown]
# ## １．散布図

# %%
# Numpyのrandomモジュールのインポート
import numpy.random as random

#　シード値の固定
random.seed(0)

# x軸のデータ
# 正規分布、平均 0、標準偏差 1　の乱数を５０個発生


# y軸のデータ
# 正規分布、平均 1、標準偏差 2　の乱数を５０個発生


# グラフの大きさの指定
# 横幅 20インチ、高さ 6インチ


# グラフの描写



# タイトルを 'Matplotlib exercise'に設定

# Xの座標名 'X'

# Yの座標名 'y'


# grid（グラフの中にある縦線と横線）の表示

# %% [markdown]
# ## ２．連続曲線

# %%
# 連続曲線

# シード値の指定
np.random.seed(0)

# 1 ～ 2000 の整数を発生させ、それを x 座標の値とする


# 平均 0, 標準偏差 1 の正規分布の乱数を２０００個発生させたデータの積み上げを y 座標とする


# グラフの大きさを ２０インチ x ６インチに設定


# ラベルを 'Sample Data' とする



# ｘ座標のラベルを 'Count' とする

# ｙ座標のラベルを 'Score' とする

# grid（グラフの中にある縦線と横線）の表示

# %% [markdown]
# ## ３．関数グラフの描画

# %% [markdown]
# ### ➀ 関数 f(x) = x ^ 2 + 5x + 5　のグラフを描画

# %%
# 関数 f(x) = x ^ 2 + 5x + 5 の定義



# x座標を -10 ～ 10 に設定


# グラフの大きさを ２０インチ x ６インチに設定


# 関数 f(x) の描画


# grid（グラフの中にある縦線と横線）の表示

# %% [markdown]
# ### ② 関数 g(x) = 5x^3 - 6x^2 + 2x + 1

# %%
# 関数 g(x) = 5x^3 - 6x^2 + 2x + 1 の定義



# x座標を -10 ～ 10 に設定


# グラフの大きさを ２０インチ x ６インチに設定


# 関数 g(x) の描画


# grid（グラフの中にある縦線と横線）の表示

# %% [markdown]
# ## ４．グラフの分割

# %%
# 関数 f(x) = x ^ 2 + 5x + 5 の定義



# 関数 g(x) = 5x^3 - 6x^2 + 2x + 1 の定義



# x座標を -10 ～ 10 に設定


# グラフの大きさを ２０インチ x ６インチに設定


# １行２列の１番目に表示

# 関数 f(x) を描画


# １行２列の２番目に表示

# 関数 g(x) を描画


# grid（グラフの中にある縦線と横線）の表示

# %% [markdown]
# ## ５．ヒストグラム

# %%
# シードの固定
random.seed(0)

# グラフの大きさ指定（２０インチｘ６インチ）


# ヒストグラムの描写
# 整数 20 ～ 80 の一様分布の乱数を５００個発生させて、data に保存


# data に保存された乱数のヒストグラムを作成
# ビンの幅 60 範囲 20 ～ 80


# grid（グラフの中にある縦線と横線）の表示
