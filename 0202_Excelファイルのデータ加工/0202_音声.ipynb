# %%
# 音声データの再生
import IPython.display as disp
disp.Audio("音声.mp3")
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# 携帯電話着信音データの再生
disp.Audio("携帯電話着信音.mp3")
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# 音声データの読み込み
import librosa
audio1, sr1 = librosa.load("音声.mp3", sr = None)
print(audio1)
print(sr1)
# Out:
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# [ 0.          0.          0.         ... -0.00419617 -0.00418091
#  -0.00402832]
# 44100

# %%
# データ形状の確認
print(audio1.shape)
print(audio1.max())
print(audio1.min())
# Out:
# (46080,)
# 0.71469116
# -0.55914307

# %%
# 電話着音信データの読み込み
audio2, sr2 = librosa.load("携帯電話着信音.mp3", sr = None)
print(audio2)
print(sr2)
print(audio2.shape)
# Out:
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# [ 0.          0.          0.         ... -0.00509644 -0.0040741
#  -0.0032196 ]
# 44100
# (101376,)

# %%
# 携帯着信音データ１秒間のみ読み込み
audio2, sr2 = librosa.load("携帯電話着信音.mp3", sr = None, offset = 0, duration = 1)
print(audio2)
print(sr2)
print(audio2.shape)
# Out:
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 9.1552734e-05 7.1716309e-04
#  1.8005371e-03]
# 44100
# (44100,)

# %%
# 切り出したデータの再生
disp.Audio(data = audio2, rate = sr2)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# 音声データ１秒間のみ読み込み
audio1, sr1 = librosa.load("音声.mp3", sr = None, offset = 0, duration = 1)
disp.Audio(data = audio1, rate = sr1)
print(audio1.shape)
# Out:
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# (44100,)

# %%
# 22050Hzでのデータ読み込み
audio1_sr22, sr1_sr22 = librosa.load("音声.mp3", sr = 22050, offset = 0, duration = 1)
print(audio1_sr22)
print(sr1_sr22)
print(audio1_sr22.shape)
# Out:
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# [0.         0.         0.         ... 0.00226999 0.00197216 0.00245217]
# 22050
# (22050,)

# %%
# 8000Hzサンプリングレートデータの作成
audio1_sr8 = librosa.resample(audio1, sr1, 8000)
print(audio1_sr8)
print(audio1_sr8.shape)
# Out:
# [0.         0.         0.         ... 0.00220963 0.00207247 0.00233328]
# (8000,)

# %%
# サンプリングプレートの取得
librosa.get_samplerate("音声.mp3")
# Out:
# 44100

# %%
# 音声データの波形
import librosa.display as libdisp
libdisp.waveplot(audio1, sr = sr1)

# %%
# 22050Hzデータの波形
libdisp.waveplot(audio1_sr22, sr = sr1_sr22)

# %%
# 8000Hzデータの波形
libdisp.waveplot(audio1_sr8, sr = 8000)

# %%
# 電話着信音データの波形
libdisp.waveplot(audio2, sr = sr2)

# %%
# データ全体に対してのRMS
import numpy as np
audio1_rms = np.sqrt(np.mean(audio1**2))
audio2_rms = np.sqrt(np.mean(audio2**2))
print(audio1_rms)
print(audio2_rms)
# Out:
# 0.1171361
# 0.079604335

# %%
# 時間別のRMS算出
rms1 = librosa.feature.rms(y = audio1)
time1 = librosa.times_like(rms1, sr = sr1)
print(rms1.shape)
rms1
# Out:
# (1, 87)
# array([[0.00000000e+00, 0.00000000e+00, 4.37028484e-06, 6.18391787e-05,
#         3.26751062e-04, 9.28368943e-04, 1.43363478e-03, 2.11810740e-03,
#         2.83041596e-03, 2.95364414e-03, 2.78270780e-03, 2.47695320e-03,
#         2.14877655e-03, 2.37163389e-03, 2.54104170e-03, 2.70688650e-03,
#         2.72346707e-03, 1.75012574e-02, 4.15570214e-02, 6.69913515e-02,
#         8.92796218e-02, 1.18809842e-01, 1.51561290e-01, 1.74796283e-01,
#         1.94208369e-01, 2.03803450e-01, 2.03455761e-01, 2.08877027e-01,
#         2.23944888e-01, 2.33912095e-01, 2.52728373e-01, 2.57646590e-01,
#         2.62712061e-01, 2.63533324e-01, 2.47948259e-01, 2.44444206e-01,
#         2.12403446e-01, 1.78452849e-01, 1.47364303e-01, 9.61778387e-02,
#         6.73959255e-02, 5.44459708e-02, 5.00177704e-02, 4.58629057e-02,
#         4.36512977e-02, 4.05723900e-02, 3.09378877e-02, 2.19067428e-02,
#         1.59059204e-02, 1.20766293e-02, 4.20553870e-02, 6.77456260e-02,
#         8.71007740e-02, 1.05747357e-01, 1.02373637e-01, 8.81036669e-02,
#         6.91893399e-02, 3.42926830e-02, 1.94472242e-02, 2.16082186e-02,
#         5.62502295e-02, 1.05036572e-01, 1.27758026e-01, 1.41277358e-01,
#         1.49730995e-01, 1.37486875e-01, 1.23453498e-01, 1.19356632e-01,
#         1.19248755e-01, 1.24109551e-01, 1.41382888e-01, 1.48257077e-01,
#         1.44536629e-01, 1.33351773e-01, 1.12941295e-01, 9.45512876e-02,
#         7.19341338e-02, 5.47677055e-02, 4.26187739e-02, 2.85786409e-02,
#         2.21760124e-02, 1.45471040e-02, 7.76437717e-03, 5.66619774e-03,
#         5.13448566e-03, 5.17266989e-03, 4.01788624e-03]], dtype=float32)

# %%
# RMSデータの可視化
from librosa.core import audio
import matplotlib.pyplot as plt

rms2 = librosa.feature.rms(y = audio2)
time2 = librosa.times_like(rms2, sr = sr2)
plt.plot(time1, rms1[0], label = "audio1")
plt.plot(time2, rms2[0], label = "audio2")
plt.legend()

# %%
# フーリエ変換
fft = np.fft.fft(audio1)
n = fft.size
amp = np.abs(fft)
freq = np.fft.fftfreq(n, d = 1 / sr1)
print(amp.shape)
print(freq.shape)
print(amp.max())
print(amp.min())
print(freq.max())
print(freq.min())
# Out:
# (44100,)
# (44100,)
# 479.54122978552937
# 4.57020163316075e-06
# 22049.0
# -22050.0

# %%
# 振幅スペクトルの可視化
plt.figure(figsize=(10, 5))
plt.plot(freq[:n//2], amp[:n//2])
plt.xlabel("Frequency [Hz]")
plt.ylabel("Amplitube")
# Out:
# Text(0, 0.5, 'Amplitube')

# %%
# 20050Hzデータでの振幅スペクトル
from IPython.core.pylabtools import figsize
fft = np.fft.fft(audio1_sr22)
n = fft.size
amp = np.abs(fft)
freq = np.fft.fftfreq(n, d = 1 / sr1_sr22)
plt.figure(figsize=(10, 5))
plt.plot(freq[:n//2], amp[:n//2])
plt.xlabel("Frequency")
plt.ylabel("Amplitude")
# Out:
# Text(0, 0.5, 'Amplitude')

# %%
# 電話の着信音の振幅スペクトル
fft = np.fft.fft(audio2)
n = fft.size
amp = np.abs(fft)
freq = np.fft.fftfreq(n, d = 1 / sr2)

plt.figure(figsize=(10, 5))
plt.plot(freq[:n//2], amp[:n//2])

# %%
# スペクトログラムデータの作成
stft = librosa.stft(audio1)
amps = np.abs(stft)
spectrogram = librosa.amplitude_to_db(amps)
print(stft.shape)
print(amps.shape)
print(spectrogram.shape)
# Out:
# (1025, 87)
# (1025, 87)
# (1025, 87)

# %%
# スペクトログラム
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectrogram, sr = sr1, x_axis = "time", y_axis = "hz", cmap = "magma")
bar = plt.colorbar()
bar.ax.set_ylabel("db")
# Out:
# Text(0, 0.5, 'db')

# %%
# 電話着信音のスペクトログラム
plt.figure(figsize=(10, 5))
stft = librosa.stft(audio2)
amps = np.abs(stft)
spectrogram = librosa.amplitude_to_db(amps)
librosa.display.specshow(spectrogram, sr = sr2, x_axis = "time", y_axis = "hz", cmap = "magma")
bar = plt.colorbar()
bar.ax.set_ylabel("db")
# Out:
# Text(0, 0.5, 'db')

# %%
# 音声データの読み込みと再生
audio1, sr1 = librosa.load("音声.mp3", sr = None)
print(audio1.shape)
disp.Audio(data = audio1, rate = sr1)
# Out:
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# (46080,)
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# 高い音への変換
audio1_pitch = librosa.effects.pitch_shift(audio1, sr1, 10)
print(audio1_pitch.shape)
disp.Audio(data = audio1_pitch, rate = sr1)
# Out:
# (46080,)
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# 低い音への変換
audio1_pitch = librosa.effects.pitch_shift(audio1, sr1, -5)
disp.Audio(data = audio1_pitch, rate = sr1)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# 電話着信音の読み込みと再生
audio2, sr2 = librosa.load("携帯電話着信音.mp3", sr = None)
print(audio2.shape)
disp.Audio(data = audio2, rate = sr2)
# Out:
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# (101376,)
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# 時間の間延び
audio2_time = librosa.effects.time_stretch(audio2, 0.5)
print(audio2_time.shape)
disp.Audio(data = audio2_time, rate = sr2)
# Out:
# (202752,)
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# 時間の短縮
audio2_time = librosa.effects.time_stretch(audio2, 2)
print(audio2_time.shape)
disp.Audio(data = audio2_time, rate = sr2)
# Out:
# (50688,)
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# wav形式での保存
import soundfile as sf

sr = 44100
sf.write("audio2_time.wav", audio2_time, sr),
# Out:
# (None,)

# %%
# 保存したデータの確認 
audio_read, sr_read = librosa.load("audio2_time.wav", sr = None)
print(audio_read.shape)
print(sr_read)
disp.Audio(data = audio_read, rate = sr_read)
# Out:
# (50688,)
# 44100
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
